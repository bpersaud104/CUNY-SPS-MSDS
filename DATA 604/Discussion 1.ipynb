# %%
import random

# %%
for i in range(1000):
    First_roll = random.randint(1, 6)
    Second_roll = random.randint(1, 6)
    Sum = First_roll + Second_roll
    if Sum == 12:
        print("You got a 12")
    else:
        print("You did not get a 12,", "you got a", Sum)
# Out:
# You got a 12
# You did not get a 12, you got a 4
# You did not get a 12, you got a 8
# You got a 12
# You did not get a 12, you got a 8
# You did not get a 12, you got a 10
# You did not get a 12, you got a 8
# You did not get a 12, you got a 7
# You did not get a 12, you got a 6
# You did not get a 12, you got a 4
# You did not get a 12, you got a 5
# You did not get a 12, you got a 6
# You did not get a 12, you got a 11
# You did not get a 12, you got a 6
# You did not get a 12, you got a 3
# You did not get a 12, you got a 7
# You did not get a 12, you got a 8
# You did not get a 12, you got a 5
# You did not get a 12, you got a 9
# You did not get a 12, you got a 10
# You did not get a 12, you got a 7
# You did not get a 12, you got a 8
# You did not get a 12, you got a 2
# You did not get a 12, you got a 7
# You did not get a 12, you got a 6
# You did not get a 12, you got a 2
# You did not get a 12, you got a 11
# You did not get a 12, you got a 4
# ...
